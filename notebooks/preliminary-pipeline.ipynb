# %% [markdown]
# # Preliminary Pipeline

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Cases data

# %%
num_records = 10_000_000

# %%
df_cases = pd.read_csv(
    './../data/COVID-19_Case_Surveillance_Public_Use_Data_with_Geography.csv',
    dtype='string',
    nrows=num_records)

# %%
df_cases = df_cases.drop(columns=['state_fips_code'])

# %%
df_cases['case_positive_specimen_interval'] = pd.to_numeric(
    df_cases['case_positive_specimen_interval'])
df_cases['case_onset_interval'] = pd.to_numeric(
    df_cases['case_onset_interval'])

# %%
df_cases
# Out:
#         case_month res_state  res_county county_fips_code       age_group  \
# 0          2020-08        KY     GRAYSON            21085    0 - 17 years
# 1          2021-01        NC      MARTIN            37117    0 - 17 years
# 2          2021-03        VT    FRANKLIN            50011  18 to 49 years
# 3          2020-09        GA     CATOOSA            13047    0 - 17 years
# 4          2021-04        PA     CLINTON            42035    0 - 17 years
# ...            ...       ...         ...              ...             ...
# 9999995    2021-02        FL   ST. LUCIE            12111       65+ years
# 9999996    2020-12        UT  WASHINGTON            49053       65+ years
# 9999997    2020-10        IL     KENDALL            17093  50 to 64 years
# 9999998    2020-07        NY      NASSAU            36059    0 - 17 years
# 9999999    2021-02        PA     DAUPHIN            42043  18 to 49 years
#
#             sex     race            ethnicity  \
# 0          <NA>     <NA>                 <NA>
# 1          <NA>     <NA>                 <NA>
# 2          <NA>     <NA>                 <NA>
# 3        Female  Unknown              Missing
# 4        Female     <NA>                 <NA>
# ...         ...      ...                  ...
# 9999995    Male    White  Non-Hispanic/Latino
# 9999996    Male    White  Non-Hispanic/Latino
# 9999997  Female     <NA>                 <NA>
# 9999998    Male  Missing              Unknown
# 9999999    Male  Unknown              Unknown
#
#          case_positive_specimen_interval  case_onset_interval  process  \
# 0                                    NaN                  0.0  Missing
# 1                                    0.0                  NaN  Missing
# 2                                    0.0                  0.0  Missing
# 3                                    NaN                  NaN  Missing
# 4                                    0.0                  0.0  Missing
# ...                                  ...                  ...      ...
# 9999995                              NaN                  NaN  Missing
# 9999996                              0.0                  0.0  Missing
# 9999997                              NaN                  0.0  Missing
# 9999998                              0.0                  NaN  Missing
# 9999999                              0.0                  NaN  Missing
#
#         exposure_yn             current_status symptom_status  hosp_yn  \
# 0           Missing  Laboratory-confirmed case    Symptomatic       No
# 1           Unknown  Laboratory-confirmed case   Asymptomatic       No
# 2               Yes  Laboratory-confirmed case    Symptomatic       No
# 3           Missing  Laboratory-confirmed case        Missing  Missing
# 4               Yes  Laboratory-confirmed case    Symptomatic       No
# ...             ...                        ...            ...      ...
# 9999995     Missing  Laboratory-confirmed case        Missing  Missing
# 9999996     Missing  Laboratory-confirmed case    Symptomatic       No
# 9999997     Missing  Laboratory-confirmed case        Missing  Missing
# 9999998     Missing              Probable Case        Missing  Missing
# 9999999     Missing  Laboratory-confirmed case        Unknown  Unknown
#
#           icu_yn death_yn underlying_conditions_yn
# 0        Missing       No                     <NA>
# 1        Unknown       No                     <NA>
# 2        Missing       No                      Yes
# 3        Missing  Missing                     <NA>
# 4             No     <NA>                     <NA>
# ...          ...      ...                      ...
# 9999995  Missing      Yes                     <NA>
# 9999996  Missing      Yes                      Yes
# 9999997  Missing  Missing                     <NA>
# 9999998  Missing  Missing                     <NA>
# 9999999  Unknown  Unknown                     <NA>
#
# [10000000 rows x 18 columns]

# %% [markdown]
# ## Counties data

# %%
use_columns = ['STATE', 'COUNTY', 'County FIPS', 'Low Income Area (LIA) County SAIPE- Score', 'Tribal Community\n(1 if yes)', 'Rural']
column_names = ['state', 'county', 'county_fips', 'low_income_score', 'tribal', 'rural']

# %%
df_counties = pd.read_csv(
    './../data/COVID-19_Community_Vulnerability_Crosswalk_-_Crosswalk_by_Census_Tract.csv',
    usecols=use_columns,
    dtype='string')

# %%
df_counties.columns = column_names

# %%
df_counties = df_counties.astype({'low_income_score': 'int64', 'rural': 'int64'})

# %%
df_counties['tribal'] = np.where(df_counties['tribal'] == 'Non-Tribal', 0, 1)
df_counties['ctract_count'] = 1

# %%
df_counties = df_counties.groupby(['state', 'county', 'county_fips']).agg(
    {'low_income_score': 'mean', 'tribal': 'sum', 'rural': 'sum', 'ctract_count': 'sum'}).reset_index()

# %%
df_counties['perc_tribal_ct'] = df_counties['tribal'] / df_counties['ctract_count']
df_counties['perc_rural_ct'] = df_counties['rural'] / df_counties['ctract_count']

# %%
df_counties = df_counties.drop(columns=['state', 'county', 'tribal', 'rural', 'ctract_count'])

# %%
df_counties
# Out:
#      county_fips  low_income_score  perc_tribal_ct  perc_rural_ct
# 0          01001                 0             0.0       0.250000
# 1          01003                 0             0.0       0.290323
# 2          01005                15             0.0       1.000000
# 3          01007                15             0.0       1.000000
# 4          01009                 7             0.0       0.888889
# ...          ...               ...             ...            ...
# 3136       56037                 0             0.0       0.250000
# 3137       56039                 0             0.0       1.000000
# 3138       56041                 0             0.0       1.000000
# 3139       56043                 0             0.0       1.000000
# 3140       56045                 0             0.0       1.000000
#
# [3141 rows x 4 columns]

# %% [markdown]
# ## Joining

# %%
df = df_cases.merge(
    df_counties, how='left', left_on='county_fips_code', right_on='county_fips')

# %%
df = df.drop(columns=['county_fips'])

# %%
df['res_county'] = df['res_county'] + ', ' + df['res_state']

# %%
df
# Out:
#         case_month res_state      res_county county_fips_code       age_group  \
# 0          2020-08        KY     GRAYSON, KY            21085    0 - 17 years
# 1          2021-01        NC      MARTIN, NC            37117    0 - 17 years
# 2          2021-03        VT    FRANKLIN, VT            50011  18 to 49 years
# 3          2020-09        GA     CATOOSA, GA            13047    0 - 17 years
# 4          2021-04        PA     CLINTON, PA            42035    0 - 17 years
# ...            ...       ...             ...              ...             ...
# 9999995    2021-02        FL   ST. LUCIE, FL            12111       65+ years
# 9999996    2020-12        UT  WASHINGTON, UT            49053       65+ years
# 9999997    2020-10        IL     KENDALL, IL            17093  50 to 64 years
# 9999998    2020-07        NY      NASSAU, NY            36059    0 - 17 years
# 9999999    2021-02        PA     DAUPHIN, PA            42043  18 to 49 years
#
#             sex     race            ethnicity  \
# 0          <NA>     <NA>                 <NA>
# 1          <NA>     <NA>                 <NA>
# 2          <NA>     <NA>                 <NA>
# 3        Female  Unknown              Missing
# 4        Female     <NA>                 <NA>
# ...         ...      ...                  ...
# 9999995    Male    White  Non-Hispanic/Latino
# 9999996    Male    White  Non-Hispanic/Latino
# 9999997  Female     <NA>                 <NA>
# 9999998    Male  Missing              Unknown
# 9999999    Male  Unknown              Unknown
#
#          case_positive_specimen_interval  case_onset_interval  ...  \
# 0                                    NaN                  0.0  ...
# 1                                    0.0                  NaN  ...
# 2                                    0.0                  0.0  ...
# 3                                    NaN                  NaN  ...
# 4                                    0.0                  0.0  ...
# ...                                  ...                  ...  ...
# 9999995                              NaN                  NaN  ...
# 9999996                              0.0                  0.0  ...
# 9999997                              NaN                  0.0  ...
# 9999998                              0.0                  NaN  ...
# 9999999                              0.0                  NaN  ...
#
#         exposure_yn             current_status symptom_status  hosp_yn  \
# 0           Missing  Laboratory-confirmed case    Symptomatic       No
# 1           Unknown  Laboratory-confirmed case   Asymptomatic       No
# 2               Yes  Laboratory-confirmed case    Symptomatic       No
# 3           Missing  Laboratory-confirmed case        Missing  Missing
# 4               Yes  Laboratory-confirmed case    Symptomatic       No
# ...             ...                        ...            ...      ...
# 9999995     Missing  Laboratory-confirmed case        Missing  Missing
# 9999996     Missing  Laboratory-confirmed case    Symptomatic       No
# 9999997     Missing  Laboratory-confirmed case        Missing  Missing
# 9999998     Missing              Probable Case        Missing  Missing
# 9999999     Missing  Laboratory-confirmed case        Unknown  Unknown
#
#           icu_yn death_yn underlying_conditions_yn low_income_score  \
# 0        Missing       No                     <NA>             15.0
# 1        Unknown       No                     <NA>             15.0
# 2        Missing       No                      Yes              0.0
# 3        Missing  Missing                     <NA>              0.0
# 4             No     <NA>                     <NA>              7.0
# ...          ...      ...                      ...              ...
# 9999995  Missing      Yes                     <NA>              0.0
# 9999996  Missing      Yes                      Yes              0.0
# 9999997  Missing  Missing                     <NA>              0.0
# 9999998  Missing  Missing                     <NA>              0.0
# 9999999  Unknown  Unknown                     <NA>              0.0
#
#          perc_tribal_ct  perc_rural_ct
# 0              0.000000       1.000000
# 1              0.000000       1.000000
# 2              0.000000       1.000000
# 3              0.000000       0.090909
# 4              0.000000       1.000000
# ...                 ...            ...
# 9999995        0.022727       0.000000
# 9999996        0.142857       0.238095
# 9999997        0.000000       0.000000
# 9999998        0.000000       0.000000
# 9999999        0.000000       0.107692
#
# [10000000 rows x 21 columns]

# %%
del df_cases
del df_counties

# %%
# %whos
# Out:
# Variable       Type         Data/Info
# -------------------------------------
# column_names   list         n=6
# df             DataFrame            case_month res_st<...>000000 rows x 21 columns]
# np             module       <module 'numpy' from '/Us<...>kages/numpy/__init__.py'>
# num_records    int          10000000
# pd             module       <module 'pandas' from '/U<...>ages/pandas/__init__.py'>
# use_columns    list         n=6

# %% [markdown]
# ## Yes/No to death_yn column

# %%
df_keep = df[~df['death_yn'].isna()]

# %%
df_keep = df_keep[(df_keep['death_yn']=='Yes') | (df_keep['death_yn']=='No')]

# %%
df_keep.reset_index(drop=True, inplace=True)

# %%
df_keep
# Out:
#         case_month res_state      res_county county_fips_code       age_group  \
# 0          2020-08        KY     GRAYSON, KY            21085    0 - 17 years
# 1          2021-01        NC      MARTIN, NC            37117    0 - 17 years
# 2          2021-03        VT    FRANKLIN, VT            50011  18 to 49 years
# 3          2021-04        OR       CROOK, OR            41013    0 - 17 years
# 4          2020-07        OK    MUSKOGEE, OK            40101    0 - 17 years
# ...            ...       ...             ...              ...             ...
# 4413808    2020-11        NY        ERIE, NY            36029    0 - 17 years
# 4413809    2021-04        NJ      BERGEN, NJ            34003  18 to 49 years
# 4413810    2020-10        OR   MULTNOMAH, OR            41051  18 to 49 years
# 4413811    2021-02        FL   ST. LUCIE, FL            12111       65+ years
# 4413812    2020-12        UT  WASHINGTON, UT            49053       65+ years
#
#             sex   race            ethnicity  case_positive_specimen_interval  \
# 0          <NA>   <NA>                 <NA>                              NaN
# 1          <NA>   <NA>                 <NA>                              0.0
# 2          <NA>   <NA>                 <NA>                              0.0
# 3        Female   <NA>                 <NA>                              NaN
# 4        Female   <NA>                 <NA>                              NaN
# ...         ...    ...                  ...                              ...
# 4413808  Female  White  Non-Hispanic/Latino                              0.0
# 4413809  Female  White  Non-Hispanic/Latino                              NaN
# 4413810  Female  White  Non-Hispanic/Latino                              NaN
# 4413811    Male  White  Non-Hispanic/Latino                              NaN
# 4413812    Male  White  Non-Hispanic/Latino                              0.0
#
#          case_onset_interval  ... exposure_yn             current_status  \
# 0                        0.0  ...     Missing  Laboratory-confirmed case
# 1                        NaN  ...     Unknown  Laboratory-confirmed case
# 2                        0.0  ...         Yes  Laboratory-confirmed case
# 3                        0.0  ...     Missing  Laboratory-confirmed case
# 4                        NaN  ...     Missing  Laboratory-confirmed case
# ...                      ...  ...         ...                        ...
# 4413808                  NaN  ...     Missing  Laboratory-confirmed case
# 4413809                  NaN  ...     Missing  Laboratory-confirmed case
# 4413810                  0.0  ...     Missing  Laboratory-confirmed case
# 4413811                  NaN  ...     Missing  Laboratory-confirmed case
# 4413812                  0.0  ...     Missing  Laboratory-confirmed case
#
#         symptom_status  hosp_yn   icu_yn death_yn underlying_conditions_yn  \
# 0          Symptomatic       No  Missing       No                     <NA>
# 1         Asymptomatic       No  Unknown       No                     <NA>
# 2          Symptomatic       No  Missing       No                      Yes
# 3          Symptomatic       No  Missing       No                     <NA>
# 4              Unknown       No  Missing       No                     <NA>
# ...                ...      ...      ...      ...                      ...
# 4413808        Missing  Missing  Missing       No                     <NA>
# 4413809        Missing  Missing  Missing       No                     <NA>
# 4413810    Symptomatic       No  Missing       No                     <NA>
# 4413811        Missing  Missing  Missing      Yes                     <NA>
# 4413812    Symptomatic       No  Missing      Yes                      Yes
#
#         low_income_score  perc_tribal_ct  perc_rural_ct
# 0                   15.0        0.000000       1.000000
# 1                   15.0        0.000000       1.000000
# 2                    0.0        0.000000       1.000000
# 3                    0.0        0.000000       1.000000
# 4                   15.0        1.000000       0.125000
# ...                  ...             ...            ...
# 4413808              0.0        0.033755       0.075949
# 4413809              0.0        0.000000       0.000000
# 4413810              0.0        0.000000       0.000000
# 4413811              0.0        0.022727       0.000000
# 4413812              0.0        0.142857       0.238095
#
# [4413813 rows x 21 columns]

# %%
del df

# %%
# %whos
# Out:
# Variable       Type         Data/Info
# -------------------------------------
# column_names   list         n=6
# df_keep        DataFrame            case_month res_st<...>413813 rows x 21 columns]
# np             module       <module 'numpy' from '/Us<...>kages/numpy/__init__.py'>
# num_records    int          10000000
# pd             module       <module 'pandas' from '/U<...>ages/pandas/__init__.py'>
# use_columns    list         n=6

# %% [markdown]
# ## Removing missing values

# %% [markdown]
# Removing all rows that have a missing, unkown, or NaN in exposure, ICU, or underlying conditions columns.

# %%
remove = df_keep['underlying_conditions_yn'].isin(['Missing', 'Unknown', pd.NA]) | df_keep['icu_yn'].isin(['Missing', 'Unknown', pd.NA]) | df_keep['exposure_yn'].isin(['Missing', 'Unknown', pd.NA])

# %%
f'Number of remaining rows: {df_keep[~remove].shape[0]:,}'
# Out:
# 'Number of remaining rows: 101,672'

# %% [markdown]
# Removing all rows that have NaN, missing, or unknown in any column

# %%
remove = ((df_keep == 'Missing') | (df_keep == 'Unknown') | df_keep.isna()).any(axis=1)

# %%
f'Number of remaining rows: {df_keep[~remove].shape[0]:,}'
# Out:
# 'Number of remaining rows: 22,706'
